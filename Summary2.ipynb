# %% [markdown]
# # Summary 2

# %%
10/2
# Out:
# 5.0

# %%
12//5
# Out:
# 2

# %%
12%5 # 5*2 + 2
# Out:
# 2

# %%
2 % 3 # 3*0 + 2
# Out:
# 2

# %%
2//3
# Out:
# 0

# %%
x = 6
y = 12
print(x & y)
# Out:
# 4

# %%
x = 6
y = 12
print(x ^ y)
# Out:
# 10

# %%
x = 6
print(x << 1)
# Out:
# 12

# %%
x = 6
print(x >> 1)
# Out:
# 3

# %%
print(12/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(12/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Операции приращения

# %%
x = 10

# %%
x+= 1 # x = x + 1
print(x)
# Out:
# 11

# %%
x = 10
x = x + 1
print(x)
# Out:
# 11

# %%
x = 10
x-= 1 # x = x - 1
print(x)
# Out:
# 9

# %%
x = 10
x *= 2 # x = x * 2
print(x)
# Out:
# 20

# %%
x = 10
x/= 2
print(x)
# Out:
# 5.0

# %%
x = 10
x**= 2 # x = x ** 2
print(x)
# Out:
# 100

# %% [markdown]
# ## Логические операции

# %%
x = True
y = False
print(x & y) # побитовая операция
print(x and y) #логическая операция
# Out:
# False
# False

# %%
x = 10
y = 6
print(x & y) # побитовая операция
print(x and y) #логическая операция
# Out:
# 2
# 6

# %%
and - 'и'
or - 'или'

# %% [markdown]
# ## Импликация

# %% [markdown]
# Предположим, что Вася будет играть в теннис с Ромой. Рома делает заявление:

# %% [markdown]
# `Если ты выиграешь, я куплю тебе мороженое`

# %% [markdown]
# * (1) Вася побеждает — получает мороженое
# * (2) Вася побеждает — не получает мороженое
# * (3) Вася проигрывает — получает мороженое
# * (4) Вася проигрывает — не получает мороженое

# %% [markdown]
# Чтобы записать высказывание Ромы символически, определим более простые высказывания:

# %% [markdown]
# * (a): ты выиграл
# * (b)
# : я куплю тебе мороженое

# %% [markdown]
# a &#8594; b

# %% [markdown]
# Эта импликация ложна только в одном случае:
#
# Когда `a` истинно, а `b` ложно — то есть Вася выиграл, но не получил мороженое
#
# При всех других исходах утверждение истинно

# %% [markdown]
# Обозначим эту ситуацию через логические уравнения для импликации:

# %% [markdown]
# * (1) Вася побеждает и получает мороженое — T &#8594; T = T
# * (2) Вася побеждает и не получает мороженое — T &#8594; F = F
# * (3) Вася проигрывает и получает мороженое — F &#8594; T = T
# * (4) Вася проигрывает и не получает мороженое — F &#8594; F = T

# %% [markdown]
# ## Законы де Моргана

# %%
A = True
B = False

# %%
print(not (A and B) == (not A) or (not B))
print(not (A or B) == not A and not B)
# Out:
#   Cell In[31], line 2
#     print(not (A or B) == not (A) and not (B))
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Двойные неравенства

# %%
x = 100
print( 5 < x < 15 ) # аналогично x>5 and x<15

# %% [markdown]
# ## Решение задач

# %% [markdown]
# Даны формулы: ¬(A ∧ (B ∨ C)) и ((¬A ∨ ¬B) ∧ (¬A ∨ ¬C)). Докажите эквивалентность этих формул, применяя закон Де Моргана

# %%
A = False
B = True
C = True
print((not (A and (B or C))) == ((not A or not B) and (not A or not C)))
# Out:
# True

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя три числа и проверяет, являются ли они уникальными (не повторяются). Выведите соответствующее сообщение на экран с помощью команды print. Используйте операторы сравнения и логические операторы для решения задачи.

# %% [markdown]
# ![image.png](attachment:25e29d56-1c28-429e-a730-98ebfce769de.png)![image.png](attachment:64c61550-9580-419d-a3d1-8db7ce374279.png)

# %%
# Числа являются уникальными - True

# Запрашиваем у пользователя три числа
num1 = int(input("Введите первое число: "))
num2 = int(input("Введите второе число: "))
num3 = int(input("Введите третье число: "))


print(num1 != num2 and num1 != num3 and num2 != num3)
# Out:
# Введите первое число:  1
# Введите второе число:  2
# Введите третье число:  3
# True

# %%
t = input("Введите первое логическое значение (True или False): ")
f = input("Введите второе логическое значение (True или False): ")

print( t and f)
print(t or f)
print(not t)
print(not f)
print(t == f)
print(t != f)
# Out:
# Введите первое логическое значение (True или False):
# Введите второе логическое значение (True или False):
# True
# True
# True
# False

# %%
x = bool(input())
print(x)
# Out:
# False
