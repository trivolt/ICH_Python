# %% [markdown]
# https://docs-python.ru/packages/biblioteka-python-telegram-bot-python/utf-kody-emoji/

# %%
print("\U0001f600")
# Out:
# 😀

# %% [markdown]
# # Строки: форматирование

# %% [markdown]
# Строковые литералы и экранирование символов. Табуляция и перевод строки:
# Строковые литералы в Python можно записывать с использованием одинарных (') или двойных (") кавычек. Если строка содержит символы, которые могут конфликтовать с кавычками, их можно экранировать с помощью обратного слеша (\). Например:

# %%
text1 = 'I\'m a programmer'  # Использование экранирования символа '
text2 = "She said: \"Hello!\""  # Использование экранирования символа "
print(text1)
print(text2)
# Out:
# I'm a programmer
# She said: "Hello!"

# %% [markdown]
# ### Escape последовательности

# %% [markdown]
# Для вставки символов табуляции и перевода строки в строковый литерал можно использовать соответствующие escape-последовательности, такие как \t и \n.

# %%
text1 = 'I\'m a programmer\nHow are you\t?'
text2 = 'Строка1\nСторка2\nСтрока3'

print(text1)
print(text2)
# Out:
# I'm a programmer
# How are you	?
# Строка1
# Сторка2
# Строка3

# %% [markdown]
# ### format()

# %% [markdown]
# В Python для форматирования строк можно использовать метод format(). Он позволяет вставлять значения аргументов в заданный шаблон строки. В самом простом случае можно использовать фигурные скобки {} в строке и передать аргументы методу format(). Например:

# %%
name = "John"
age = 30
text = "My name is {} and I'm {} years old".format(name, age)
print(text)
# Out:
# My name is John and I'm 30 years old

# %%
name = "John"
age = 30
text = "My name is" + " " + name +" " + "and I'm" + " "+ str(age)+ " " + "years old"
print(text)
# Out:
# My name is John and I'm 30 years old

# %% [markdown]
# Можно также явно указывать индексы аргументов или использовать именованные подстановки для более гибкого форматирования:

# %%
text1 = "{0} {1} {0}".format("I", "like")  # Вставка аргументов по индексу
text2 = "{name} is {age} years old".format(name="John", age=30)  # Использование именованных подстановок
print(text1)
print(text2)
# Out:
# I like I
# John is 30 years old

# %% [markdown]
# ## Продвинутые возможности format()

# %% [markdown]
# Продвинутые возможности функции format():

# %% [markdown]
# Метод format() предоставляет дополнительные возможности для форматирования строк, такие как управление выравниванием, указание точности чисел, форматирование чисел в различных системах счисления и др. Например:

# %%
price = 9.99999
quantity = 5
total = price * quantity
text = "Total: ${:.2f}".format(total)  # Указание точности числа до двух знаков после запятой
print(total)
print(text)
# Out:
# 49.99995
# Total: $50.00

# %% [markdown]
# Еще примеры ...

# %%
# аргументы по умолчанию 
print("Hello {}, your balance is {}.".format("Adam", 230.2346)) 

# позиционные аргументы 
print("Hello {0}, your balance is {1}.".format("Adam", 230.2346)) 

# аргументы ключевые слова 
print("Hello {name}, your balance is {blc}.".format(name="Adam", blc=230.2346)) 

# смешанные аргументы 
print("Hello {0}, your balance is {blc}.".format("Adam", blc=230.2346))
# Out:
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.

# %%
# целочисленные аргументы 
print("The number is:{:d}".format(123))

# целые числа с минимальной шириной 
print("{:5d}".format(12)) 

# аргументы с плавающей точкой 
print("The float number is:{:f}".format(123.4567898)) 

# заполнение для чисел с плавающей точкой 
print("{:8.3f}".format(12.2346))

# восьмеричный, двоичный и шестнадцатеричный формат 
print("bin: {0:b}, oct: {0:o}, hex: {0:x}".format(12))
# Out:
# The number is:123
#    12
# The float number is:123.456790
#   12.235
# bin: 1100, oct: 14, hex: c

# %% [markdown]
# ![image.png](attachment:545c59c4-604c-4e6f-aadb-e62504f52d56.png)

# %% [markdown]
# ![image.png](attachment:5cc802f5-611f-40ee-aab2-61bbc6ed93ca.png)

# %% [markdown]
# ### Динамическое форматирование

# %%
# динамический шаблон формата строки 
string = "{:{fill}{align}{width}}" 

# передача кодов формата в качестве аргументов 
print(string.format('cat', fill='*', align='^', width=5)) 

# динамический шаблон формата float 
num = "{:{align}{width}.{precision}f}" 

# передача кодов формата в качестве аргументов 
print(num.format(123.236, align='<', width=8, precision=2))

# %% [markdown]
# ### Упражнение

# %% [markdown]
# Используя format, спросить имя и возраст, вывести:
# "Привет ..., тебе ... лет".

# %%
name = input("Введите ваше имя: ")
age = input("Введите ваш возраст: ")
print("Привет {0}, тебе {1} лет.".format(name, age))
# Out:
# Введите ваше имя:  John
# Введите ваш возраст:  200
# Привет John, тебе 200 лет.

# %% [markdown]
# ### C-style форматирование

# %% [markdown]
# Python поддерживает C-style форматирование строк с использованием спецификаторов формата, таких как %d для целых чисел и %s для строк. Например:

# %%
name = "John"
print("Hello, %s!" % name)
# Out:
# Hello, John!

# %% [markdown]
# Используя C-style, спросить имя и возраст, вывести:
# "Привет ..., тебе ... лет".

# %%
name = "John"
age = 30
text = "My name is %s and I'm %s years old" % (name, age)
print(text)
# Out:
# My name is John and I'm 30 years old

# %% [markdown]
# ### Использование f-строк

# %% [markdown]
# С Python 3.6 появилась новая возможность для форматирования строк - f-строки. Они позволяют встраивать выражения и переменные прямо в строку, используя префикс f. Например:

# %%
name = "John"
age = 30
text = f"My name is {name} and I'm {age} years old"
print(text)
# Out:
# My name is John and I'm 30 years old

# %% [markdown]
# F-строки поддерживают использование форматных спецификаторов для управления выводом значений. Например:

# %%
price = 9.99
quantity = 5
total = price * quantity
text = f"Total: ${total:.2f}"  # Указание точности числа до двух знаков после запятой
print(text)
# Out:
# Total: $49.95

# %% [markdown]
# F-строки позволяют использовать позиционные аргументы и = для управления выравниванием. Например:

# %%
name = "John"
age = 30
text = f"{name:+^10} is {age:=^10} years old"
print(text)
# Out:
# +++John+++ is ====30==== years old

# %% [markdown]
# ### Решение задач

# %% [markdown]
# 1. На вход приходят имя-фамилия-пол-возраст. Программа выводит приветственную строку, в которую вставлены имя-фамилия и пишет дополнительно что средний возраст всех людей твоего пола среди встреченных ранее – такой-то. Реализовать без хранения списков или иных массивов в памяти.

# %%
name = input('Введите имя ')
last_name = input('Введите фамилию ')
gender = input('Введите пол ')
age = int(input('Введите возраст '))

# ввода информации о 10 человек
'''
gender1 = 'm'
age1 = 

gender2 = 'f'
age2 = 

...

gender10 = 'm'
age10 = 
'''
i = 0
summ = 0
cnt = 0
while i<3:
    print(f'{i+1}).')
    gender_temp = input('Введите пол ')
    age_temp = int(input('Введите возраст '))
    if gender == gender_temp:
        summ += age_temp
        cnt += 1
    i+=1

avg_age = summ / cnt

print(f'{name} {last_name} среди твоего пола средний возраст: {avg_age}')
# Out:
# Введите имя  John
# Введите фамилию  Silver
# Введите пол  m
# Введите возраст  30
# 1).
# Введите пол  m
# Введите возраст  10
# 2).
# Введите пол  f
# Введите возраст  10
# 3).
# Введите пол  m
# Введите возраст  10
# John Silver среди твоего пола средний возраст: 10.0

# %% [markdown]
# 2. Напишите программу, которая выводит на экран следующий текст, используя строковые литералы и экранирование символов:
#
# "Hello\tWorld!\nHow are you?"
#
# Выведите результат на экран с помощью команды print.
#
# Пример вывода:
#
# Hello	World!
#
# How are you?

# %%
s = "Hello\tWorld!\nHow are you?"
print(s)
# Out:
# Hello	World!
# How are you?

# %% [markdown]
# ### Полезные материалы
# 1. Форматирование строк. Метод format https://pythonworld.ru/osnovy/formatirovanie-strok-metod-format.html
# 2. Форматирование строк. Оператор %
# https://pythonworld.ru/osnovy/formatirovanie-strok-operator.html

# %% [markdown]
# ### Вопросы для закрепления
# 1. Какие недостатки есть у всех методов форматирования, которые использовались до f-строк?
#
# 2. Очевидно, что если у нас простое форматирование в виде вставить значение двух переменных в два места в строке, то мы можем это сделать просто сложением (=конкатенацией) строк. В чем, помимо каких-то эстетических моментов, огромный плюс форматирования?
#
# 3. Перечислите символы, которые нужно экранировать в строках. Можно ли однозначно ответить на этот вопрос?

# %% [markdown]
# ### Вспоминалки )))

# %%
text = 'Фамилия Имя Отчество'
print(text[:7])
# Out:
# Фамилия

# %%
print(text[-8:])
# Out:
# Отчество

# %%
print(text[12:])
# Out:
# Отчество

# %%
ind = text.find(' ')
ind
# Out:
# 7

# %%
text[ind+1:]
# Out:
# 'Имя Отчество'

# %%
text[::2]
# Out:
# 'ФмляИяОчсв'

# %%
text[8]
# Out:
# 'И'

# %%
text
# Out:
# 'Фамилия Имя Отчество'

# %%
s = text.lower()
print(s)
# Out:
# фамилия имя отчество

# %%
s.count('о')
# Out:
# 2
